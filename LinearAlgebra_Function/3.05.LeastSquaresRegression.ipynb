# %% [markdown]
# # Least Squares Regression in Python

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

# %%
# generate x and y
x = np.linspace(0, 1, 101)
y = 1 + x + x * np.random.random(len(x))

# %%
# assemble matrix A
A = np.vstack([x, np.ones(len(x))]).T
print(A)

# turn y into a column vector
y = y[:, np.newaxis]
print(y)
# Out:
# [[0.   1.  ]
#  [0.01 1.  ]
#  [0.02 1.  ]
#  [0.03 1.  ]
#  [0.04 1.  ]
#  [0.05 1.  ]
#  [0.06 1.  ]
#  [0.07 1.  ]
#  [0.08 1.  ]
#  [0.09 1.  ]
#  [0.1  1.  ]
#  [0.11 1.  ]
#  [0.12 1.  ]
#  [0.13 1.  ]
#  [0.14 1.  ]
#  [0.15 1.  ]
#  [0.16 1.  ]
#  [0.17 1.  ]
#  [0.18 1.  ]
#  [0.19 1.  ]
#  [0.2  1.  ]
#  [0.21 1.  ]
#  [0.22 1.  ]
#  [0.23 1.  ]
#  [0.24 1.  ]
#  [0.25 1.  ]
#  [0.26 1.  ]
#  [0.27 1.  ]
#  [0.28 1.  ]
#  [0.29 1.  ]
#  [0.3  1.  ]
#  [0.31 1.  ]
#  [0.32 1.  ]
#  [0.33 1.  ]
#  [0.34 1.  ]
#  [0.35 1.  ]
#  [0.36 1.  ]
#  [0.37 1.  ]
#  [0.38 1.  ]
#  [0.39 1.  ]
#  [0.4  1.  ]
#  [0.41 1.  ]
#  [0.42 1.  ]
#  [0.43 1.  ]
#  [0.44 1.  ]
#  [0.45 1.  ]
#  [0.46 1.  ]
#  [0.47 1.  ]
#  [0.48 1.  ]
#  [0.49 1.  ]
#  [0.5  1.  ]
#  [0.51 1.  ]
#  [0.52 1.  ]
#  [0.53 1.  ]
#  [0.54 1.  ]
#  [0.55 1.  ]
#  [0.56 1.  ]
#  [0.57 1.  ]
#  [0.58 1.  ]
#  [0.59 1.  ]
#  [0.6  1.  ]
#  [0.61 1.  ]
#  [0.62 1.  ]
#  [0.63 1.  ]
#  [0.64 1.  ]
#  [0.65 1.  ]
# ...

# %%
# Direct least square regression
# inv(A^T * A) * A^T * y
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)
# Out:
# [[1.36458088]
#  [1.0275982 ]]

# %%
# plot the results
plt.figure(figsize = (10,8))
plt.plot(x, y, 'b.')
plt.plot(x, alpha[0]*x + alpha[1], 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # Use the pseudoinverse

# %% [markdown]
# pseudoinverse = inv(A^T * A) * A^T

# %%
pinv = np.linalg.pinv(A)
alpha = pinv.dot(y)
print(alpha)
# Out:
# [1.40848858 1.02460172]

# %%
# plot the results
plt.figure(figsize = (10,8))
plt.plot(x, y, 'b.')
plt.plot(x, alpha[0]*x + alpha[1], 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # Use optimize.curve_fit from scipy

# %%
# generate x and y
x = np.linspace(0, 1, 101)
y = 1 + x + x * np.random.random(len(x))

def func(x, a, b):
    y = a*x + b
    return y

result = optimize.curve_fit(func, xdata = x, ydata = y)[0]
print(result)
# Out:
# [1.40848859 1.02460172]

# %%
plt.figure(figsize = (10,8))
plt.plot(x, y, 'r.', label='original')
plt.plot(x, func(x, *result), 'b', label='fitting')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.show()
